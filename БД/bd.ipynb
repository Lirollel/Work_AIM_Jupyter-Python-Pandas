# %%
import oracledb
import pandas as pd

oracledb.init_oracle_client('C:\\Users\\KlimovaAnnaA\\Documents\\MyFiles\\Oracle\\instantclient_21_13')

# %%
connection = oracledb.connect(user="RISKCUSTOM", password="xxRiscRccess174!", host="exatest2-scan.moscow.eurochem.ru", port=1521, service_name='riskdev.moscow.eurochem.ru', disable_oob= True)

# %%
query = """SELECT * FROM "RISKACCESS"."sapPositionArrears" WHERE "reportDate" = TO_DATE('29/02/24', 'DD/MM/YY') AND "productType" in (130,131,132,133)"""
data = pd.read_sql(query, con=connection)
# Out:
# C:\Users\KlimovaAnnaA\AppData\Local\Temp\ipykernel_3148\27959075.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query, con=connection)

# %%
data
# Out:
#           ##batch_id ##deleted          ##inserted ##origin_name companyCode  \
# 0    34099078@WHPROD         N 2024-02-29 07:13:33           SAP        E100
# 1    34099078@WHPROD         N 2024-02-29 07:13:33           SAP        E100
# 2    34099078@WHPROD         N 2024-02-29 07:13:33           SAP        E100
# 3    34099078@WHPROD         N 2024-02-29 07:13:33           SAP        V100
# 4    34099078@WHPROD         N 2024-02-29 07:13:33           SAP        V100
# ..               ...       ...                 ...           ...         ...
# 792  34099078@WHPROD         N 2024-02-29 07:13:33           SAP        1R00
# 793  34099078@WHPROD         N 2024-02-29 07:13:33           SAP        1L00
# 794  34099078@WHPROD         N 2024-02-29 07:13:33           SAP        1100
# 795  34099078@WHPROD         N 2024-02-29 07:13:33           SAP        1100
# 796  34099078@WHPROD         N 2024-02-29 07:13:33           SAP        1100
#
#              companyName valuationAreaId           valuationAreaName  \
# 0    АО "Ковдорский ГОК"             001  Оперативная область оценки
# 1    АО "Ковдорский ГОК"             001  Оперативная область оценки
# 2    АО "Ковдорский ГОК"             001  Оперативная область оценки
# 3    АО "Енисейская ТГК"             001  Оперативная область оценки
# 4    АО "Енисейская ТГК"             001  Оперативная область оценки
# ..                   ...             ...                         ...
# 792            ООО "СГК"             001  Оперативная область оценки
# 793  МК «СУЭК ЛТД» (ООО)             001  Оперативная область оценки
# 794            АО "СУЭК"             001  Оперативная область оценки
# 795            АО "СУЭК"             001  Оперативная область оценки
# 796            АО "СУЭК"             001  Оперативная область оценки
#
#     valuationClassId                                 valuationClassName  ...  \
# 0               0102  Финансовая кредиторская задолженность (долгоср...  ...
# 1               0102  Финансовая кредиторская задолженность (долгоср...  ...
# 2               0102  Финансовая кредиторская задолженность (долгоср...  ...
# 3               0102  Финансовая кредиторская задолженность (долгоср...  ...
# 4               0102  Финансовая кредиторская задолженность (долгоср...  ...
# ..               ...                                                ...  ...
# 792             0101  Финансовая кредиторская задолженность (краткос...  ...
# 793             0242                      Займы выданные (долгосрочные)  ...
# 794             0101  Финансовая кредиторская задолженность (краткос...  ...
# 795             0101  Финансовая кредиторская задолженность (краткос...  ...
# 796             0101  Финансовая кредиторская задолженность (краткос...  ...
#
#     reportDate_month securedContractDate_year securedContractDate_quarter  \
# 0                  2                      NaN                         NaN
# 1                  2                      NaN                         NaN
# 2                  2                      NaN                         NaN
# 3                  2                      NaN                         NaN
# 4                  2                      NaN                         NaN
# ..               ...                      ...                         ...
# 792                2                      NaN                         NaN
# 793                2                      NaN                         NaN
# 794                2                      NaN                         NaN
# 795                2                      NaN                         NaN
# 796                2                      NaN                         NaN
#
#     securedContractDate_month termEnd_year termEnd_quarter termEnd_month  \
# 0                         NaN         2026               2             4
# 1                         NaN         2026               2             5
# 2                         NaN         2026               2             5
# 3                         NaN         2029               3             7
# 4                         NaN         2029               3             7
# ..                        ...          ...             ...           ...
# 792                       NaN         2033               1             3
# 793                       NaN         2024               4            12
# 794                       NaN         2031               4            12
# 795                       NaN         2024               4            12
# 796                       NaN         2024               3             9
#
#     termStart_year termStart_quarter termStart_month
# 0             2021                 2               4
# 1             2021                 2               5
# 2             2021                 2               5
# 3             2023                 2               4
# 4             2023                 2               4
# ..             ...               ...             ...
# 792           2022                 2               4
# 793           2021                 1               1
# 794           2021                 4              12
# 795           2020                 1               1
# 796           2023                 3               9
#
# [797 rows x 147 columns]
