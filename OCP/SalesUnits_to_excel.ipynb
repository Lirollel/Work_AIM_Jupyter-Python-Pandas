# %%
import sys
sys.path.append("C:\\Users\\KlimovaAnnaA\\Documents\\MyFiles\\Projects\\Working_attributes")
from Imports import *

# %%
data = export_from_RISKCUSTOM(f"""select * from "RISKACCESS"."mdgSalesUnits" """)
data.to_excel('SalesUnits.xlsx')
# Out:
# C:\Users\KlimovaAnnaA\Documents\MyFiles\Projects\Working_attributes\Defs.py:88: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data_export = pd.read_sql(query, con=connection)

# %%
data[data.id.str.contains('CH')].loc[:,'company_id':]
# Out:
#      company_id salesUnitGroup sapId                    sapName sapCity  \
# 62    5400478.0           None  E940                       None    None
# 74    5361810.0           None  E960                       None    None
# 210  54004781.0           None  E840  EuroChem Group AG Trading    None
#
#     sapCountryCode sapSuCurrency oebs12Id                    oebs12Name  \
# 62              CH           USD      161      CHEAG: EuroChem Group AG
# 74            None           USD      123  CHTRD: EuroChem Trading GmbH
# 210             CH           USD     None                          None
#
#     oebs12ShortCode  ... affiliatedHolding businessSegmentDetailed quantumId  \
# 62            CHEAG  ...              None          TRADING Europe     CHEAG
# 74            CHTRD  ...              None          TRADING Europe     CHTRD
# 210            None  ...              None          TRADING Europe      None
#
# ...
