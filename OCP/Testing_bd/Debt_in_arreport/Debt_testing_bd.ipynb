# %%
import sys
sys.path.append("C:\\Users\\KlimovaAnnaA\\Documents\\MyFiles\\Projects\\Working_attributes")
from Imports import *

# %%
work_data = '31/05/24'

# %%
query = """
select *
from RISKACCESS."unifiedARReport" 
where "sourceSystem" = 'SAP ERP'
fetch first 3 rows only
"""
data_cols = export_from_RISKCUSTOM(query)
cols_str = str(data_cols.columns.tolist()).replace('\'','\"')[1:-1]
# Out:
# C:\Users\KlimovaAnnaA\Documents\MyFiles\Projects\Working_attributes\Defs.py:88: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data_export = pd.read_sql(query, con=connection)

# %%
query = f"""
select * from (
select {cols_str},
case 
when ("glAccount" like '58%' or "glAccount" like '59%')
--"reportType" = 'AR' and 
then 'займы выданные'
when ("glAccount" like '66%' or "glAccount" like '67%')
--"reportType" = 'AP' and 
then 'займы полученные'
end as "debt_type"
from RISKACCESS."unifiedARReport" 
--where "sourceSystem" = 'SAP ERP'
where "reportDate" = TO_DATE('{work_data}', 'DD/MM/YY')
--fetch first 3 rows only
)
where "debt_type" is not null
"""
data_export = export_from_RISKCUSTOM(query)
data_export.head(5)
# Out:
# C:\Users\KlimovaAnnaA\Documents\MyFiles\Projects\Working_attributes\Defs.py:88: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data_export = pd.read_sql(query, con=connection)
#         ##batch_id ##deleted          ##inserted ##origin_name rowType  \
# 0  37415187@WHPROD         N 2024-06-15 07:22:18        WHFLEX       M
# 1  37415187@WHPROD         N 2024-06-15 07:22:18        WHFLEX       M
# 2  37415187@WHPROD         N 2024-06-15 07:22:18        WHFLEX       M
# 3  37415187@WHPROD         N 2024-06-15 07:22:18        WHFLEX       M
# 4  37415187@WHPROD         N 2024-06-15 07:22:18        WHFLEX       M
#
#   reportType reportDate                             partyInternational  \
# 0         AP 2024-05-31  Recursos a pagar - compartilhamento de gastos
# ...

# %%
data_export.shape
# data_export.loc[:, 'orderNumber':]
# data_export[['orgName','companyCode','amount','currencyCode','debtDescription','sourceSystem','sourceTable','holding','insertToSource','documentNumberRef']]
# Out:
# (13, 167)

# %%
query = f"""
select *
from RISKACCESS."unifiedARReport" 
--where "sourceSystem" = 'SAP ERP'
where ("glAccount" like '58%' or "glAccount" like '59%'
or "glAccount" like '66%' or "glAccount" like '67%')
and "reportDate" = TO_DATE('{work_data}', 'DD/MM/YY')
fetch first 3 rows only
"""
data_export = export_from_RISKCUSTOM(query)
data_export.sourceSystem
# Out:
# C:\Users\KlimovaAnnaA\Documents\MyFiles\Projects\Working_attributes\Defs.py:88: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data_export = pd.read_sql(query, con=connection)
# 0    SAP_HRG
# 1    SAP_HRG
# 2    SAP_HRG
# Name: sourceSystem, dtype: object
